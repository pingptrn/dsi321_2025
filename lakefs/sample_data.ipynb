# %%
import pandas as pd
df = pd.read_parquet("/Users/pattaranitjaroennovapat/Desktop/50d7be7df80545e98198522aefbe4bbc-0.parquet")
df.head(10)
# Out:
#              timestamp stationID                                nameTH  \
# 0  2025-05-18 15:00:00       02t  มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา
# 1  2025-05-18 15:00:00       03t            ริมถนนทางหลวงหมายเลข 3902
# 2  2025-05-18 15:00:00       11t                 การเคหะชุมชนห้วยขวาง
# 3  2025-05-18 15:00:00       12t                   โรงเรียนนนทรีวิทยา
# 4  2025-05-18 15:00:00       50t                   โรงพยาบาลจุฬาลงกรณ์
# 5  2025-05-18 15:00:00       52t                   การไฟฟ้าย่อยธนบุรี
# 6  2025-05-18 15:00:00       53t               สถานีตำรวจนครบาลโชคชัย
# 7  2025-05-18 15:00:00       54t                   การเคหะชุมชนดินแดง
# 8  2025-05-18 15:00:00       59t                      กรมประชาสัมพันธ์
# 9  2025-05-18 15:00:00       61t  โรงเรียนบดินทรเดชา (สิงห์ สิงหเสนี)
#
#                                         nameEN  \
# 0       Bansomdejchaopraya Rajabhat University
# 1                   Highway NO.3902 km.13 +600
# 2                  National Housing  Huaykwang
# ...
